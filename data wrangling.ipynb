# %%
import numpy as np
import pandas as pd

# %%
dependent_var = ['RUL']
index_columns_names =  ["id","Cycle"]
operational_settings_columns_names = ["setting"+str(i) for i in range(1,4)]
sensor_measure_columns_names =["s"+str(i) for i in range(1,22)]
input_file_column_names = index_columns_names + operational_settings_columns_names + sensor_measure_columns_names

# %%
df_train = pd.read_csv('data/data_train.txt',delim_whitespace=True,names=input_file_column_names)

rul = pd.DataFrame(df_train.groupby('id')['Cycle'].max()).reset_index()
rul.columns = ['id', 'max']
df_train = df_train.merge(rul, on=['id'], how='left')
df_train['ttf'] = df_train['max'] - df_train['Cycle']
df_train.drop('max', axis=1, inplace=True)

df_train.head()
# Out:
#    id  Cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0007   -0.0004     100.0  518.67  641.82  1589.70  1400.60
# 1   1      2    0.0019   -0.0003     100.0  518.67  642.15  1591.82  1403.14
# 2   1      3   -0.0043    0.0003     100.0  518.67  642.35  1587.99  1404.20
# 3   1      4    0.0007    0.0000     100.0  518.67  642.35  1582.79  1401.87
# 4   1      5   -0.0019   -0.0002     100.0  518.67  642.37  1582.85  1406.22
#
#       s5  ...      s13      s14     s15   s16  s17   s18    s19    s20  \
# 0  14.62  ...  2388.02  8138.62  8.4195  0.03  392  2388  100.0  39.06
# 1  14.62  ...  2388.07  8131.49  8.4318  0.03  392  2388  100.0  39.00
# 2  14.62  ...  2388.03  8133.23  8.4178  0.03  390  2388  100.0  38.95
# 3  14.62  ...  2388.08  8133.83  8.3682  0.03  392  2388  100.0  38.88
# 4  14.62  ...  2388.04  8133.80  8.4294  0.03  393  2388  100.0  38.90
#
#        s21  ttf
# 0  23.4190  191
# 1  23.4236  190
# 2  23.3442  189
# ...

# %%
df_test = pd.read_csv('data/data_test.txt', delim_whitespace=True, names=input_file_column_names)

# %%
df_test.head()
# Out:
#    id  Cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1    0.0023    0.0003     100.0  518.67  643.02  1585.29  1398.21
# 1   1      2   -0.0027   -0.0003     100.0  518.67  641.71  1588.45  1395.42
# 2   1      3    0.0003    0.0001     100.0  518.67  642.46  1586.94  1401.34
# 3   1      4    0.0042    0.0000     100.0  518.67  642.44  1584.12  1406.42
# 4   1      5    0.0014    0.0000     100.0  518.67  642.51  1587.19  1401.92
#
#       s5  ...     s12      s13      s14     s15   s16  s17   s18    s19  \
# 0  14.62  ...  521.72  2388.03  8125.55  8.4052  0.03  392  2388  100.0
# 1  14.62  ...  522.16  2388.06  8139.62  8.3803  0.03  393  2388  100.0
# 2  14.62  ...  521.97  2388.03  8130.10  8.4441  0.03  393  2388  100.0
# 3  14.62  ...  521.38  2388.05  8132.90  8.3917  0.03  391  2388  100.0
# 4  14.62  ...  522.15  2388.03  8129.54  8.4031  0.03  390  2388  100.0
#
#      s20      s21
# 0  38.86  23.3735
# 1  39.02  23.3916
# ...

# %%
df_train.describe()
# Out:
#                  id         Cycle      setting1      setting2  setting3  \
# count  20631.000000  20631.000000  20631.000000  20631.000000   20631.0
# mean      51.506568    108.807862     -0.000009      0.000002     100.0
# std       29.227633     68.880990      0.002187      0.000293       0.0
# min        1.000000      1.000000     -0.008700     -0.000600     100.0
# 25%       26.000000     52.000000     -0.001500     -0.000200     100.0
# 50%       52.000000    104.000000      0.000000      0.000000     100.0
# 75%       77.000000    156.000000      0.001500      0.000300     100.0
# max      100.000000    362.000000      0.008700      0.000600     100.0
#
#                  s1            s2            s3            s4            s5  \
# count  2.063100e+04  20631.000000  20631.000000  20631.000000  2.063100e+04
# mean   5.186700e+02    642.680934   1590.523119   1408.933782  1.462000e+01
# std    6.537152e-11      0.500053      6.131150      9.000605  3.394700e-12
# ...

# %%
df_test.describe()
# Out:
#                  id         Cycle      setting1      setting2  setting3  \
# count  13096.000000  13096.000000  13096.000000  13096.000000   13096.0
# mean      51.543907     76.836515     -0.000011      0.000004     100.0
# std       28.289423     53.057749      0.002203      0.000294       0.0
# min        1.000000      1.000000     -0.008200     -0.000600     100.0
# 25%       28.000000     33.000000     -0.001500     -0.000200     100.0
# 50%       52.000000     69.000000      0.000000      0.000000     100.0
# 75%       76.000000    113.000000      0.001500      0.000300     100.0
# max      100.000000    303.000000      0.007800      0.000700     100.0
#
#                  s1            s2            s3            s4            s5  \
# count  1.309600e+04  13096.000000  13096.000000  13096.000000  1.309600e+04
# mean   5.186700e+02    642.475088   1588.099204   1404.735362  1.462000e+01
# std    6.014263e-11      0.400899      5.003274      6.688309  2.671743e-12
# ...

# %%
RUL = pd.read_csv('data/data_truth.txt',delim_whitespace=True,names=['ttf'])

# %%
df_train['label_bnc'] = [1 if i < 30 else 0 for i in df_train.ttf]
RUL['label_bnc'] = [1 if i <30 else 0 for i in RUL.ttf]

# %%
df_train.shape
# Out:
# (20631, 28)

# %%
df_train.isnull().sum()
# Out:
# id           0
# Cycle        0
# setting1     0
# setting2     0
# setting3     0
# s1           0
# s2           0
# s3           0
# s4           0
# s5           0
# s6           0
# s7           0
# s8           0
# s9           0
# s10          0
# s11          0
# s12          0
# s13          0
# s14          0
# s15          0
# s16          0
# s17          0
# s18          0
# s19          0
# s20          0
# s21          0
# ttf          0
# label_bnc    0
# dtype: int64

# %%
df_train.dtypes
# Out:
# id             int64
# Cycle          int64
# setting1     float64
# setting2     float64
# setting3     float64
# s1           float64
# s2           float64
# s3           float64
# s4           float64
# s5           float64
# s6           float64
# s7           float64
# s8           float64
# s9           float64
# s10          float64
# s11          float64
# s12          float64
# s13          float64
# s14          float64
# s15          float64
# s16          float64
# s17            int64
# s18            int64
# s19          float64
# s20          float64
# s21          float64
# ttf            int64
# label_bnc      int64
# dtype: object

# %%
def prepare_test_data(df_test_in, df_truth_in, period):
    
    df_tst_last_cycle = pd.DataFrame(df_test_in.groupby('id')['Cycle'].max())
    
    df_tst_last_cycle.reset_index(level=0, inplace=True)
    df_tst_last_cycle.columns = ['id', 'last_cycle']
    
    df_test_in = pd.merge(df_test_in, df_tst_last_cycle, on='id')


    df_test_in = df_test_in[df_test_in['Cycle'] == df_test_in['last_cycle']]

    df_test_in.drop(['last_cycle'], axis=1, inplace=True)
    
    df_test_in.reset_index(drop=True, inplace=True)
    
    df_test_in = pd.concat([df_test_in, df_truth_in], axis=1)
    return df_test_in

# %%
data_test = prepare_test_data(df_test, RUL, 15)
data_test.head()
# Out:
#    id  Cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1     31   -0.0006    0.0004     100.0  518.67  642.58  1581.22  1398.91
# 1   2     49    0.0018   -0.0001     100.0  518.67  642.55  1586.59  1410.83
# 2   3    126   -0.0016    0.0004     100.0  518.67  642.88  1589.75  1418.89
# 3   4    106    0.0012    0.0004     100.0  518.67  642.78  1594.53  1406.88
# 4   5     98   -0.0013   -0.0004     100.0  518.67  642.27  1589.94  1419.36
#
#       s5  ...      s14     s15   s16  s17   s18    s19    s20      s21  ttf  \
# 0  14.62  ...  8130.11  8.4024  0.03  393  2388  100.0  38.81  23.3552  112
# 1  14.62  ...  8126.90  8.4505  0.03  391  2388  100.0  38.81  23.2618   98
# 2  14.62  ...  8131.46  8.4119  0.03  395  2388  100.0  38.93  23.2740   69
# 3  14.62  ...  8133.64  8.4634  0.03  395  2388  100.0  38.58  23.2581   82
# 4  14.62  ...  8125.74  8.4362  0.03  394  2388  100.0  38.75  23.4117   91
#
#    label_bnc
# 0          0
# 1          0
# ...

# %%
df_train
# Out:
#         id  Cycle  setting1  setting2  setting3      s1      s2       s3  \
# 0        1      1   -0.0007   -0.0004     100.0  518.67  641.82  1589.70
# 1        1      2    0.0019   -0.0003     100.0  518.67  642.15  1591.82
# 2        1      3   -0.0043    0.0003     100.0  518.67  642.35  1587.99
# 3        1      4    0.0007    0.0000     100.0  518.67  642.35  1582.79
# 4        1      5   -0.0019   -0.0002     100.0  518.67  642.37  1582.85
# ...    ...    ...       ...       ...       ...     ...     ...      ...
# 20626  100    196   -0.0004   -0.0003     100.0  518.67  643.49  1597.98
# 20627  100    197   -0.0016   -0.0005     100.0  518.67  643.54  1604.50
# 20628  100    198    0.0004    0.0000     100.0  518.67  643.42  1602.46
# 20629  100    199   -0.0011    0.0003     100.0  518.67  643.23  1605.26
# 20630  100    200   -0.0032   -0.0005     100.0  518.67  643.85  1600.38
#
#             s4     s5  ...      s14     s15   s16  s17   s18    s19    s20  \
# ...

# %%
data_test.to_csv('data/test.csv', index=False)
df_train.to_csv('data/train.csv',index=False)

# %%
RUL.to_csv('data/RUL.csv', index=False)
